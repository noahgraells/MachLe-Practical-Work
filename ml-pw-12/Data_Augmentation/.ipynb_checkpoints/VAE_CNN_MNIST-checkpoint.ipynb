# %% [markdown]
# # **Data Augmentation** using Variational Autoencoder
#
# This notebook will guide you trough the use of a variational convolutional autoencoder in the task of data augmentation. The main objective is to use a convolutional autoencoder to reconstruct of the **"2"** images in the MNIST database in order to augment a database. (You can try different digits)

# %% [markdown]
# ## A little bit about Autoencoder in general
#
# Autoencoder's goal is to learn how to reconstruct the input-data. But how is it helpful? The trick is their structure. The first part of the network is what we refer to as the Encoder. It receives the input and it encodes it in a latent space of a lower dimension. The second part (the Decoder) takes that vector and decode it in order to produce the original input.
#
# Therefore, we can apply them to reproduce the same but a little different or even better data. Examples are:
#
# ***Data Denoising***: Feed them with a noisy image and train them to output the same image but without the noise
#
# ***Training data augmentation***
#
# ***Anomaly Detection***: Train them on a single class so that every anomaly gives a large reconstruction error.
#
# Variational autoencoders are trained to learn the probability distribution that models the input-data and not the function that maps the input and the output. It then samples points from this distribution and feed them to the decoder to generate new input data samples.
#
# One of the key aspects of VAE is the **loss function**. Most commonly, it consists of two components. The reconstruction loss measures how different the reconstructed data are from the original data (binary cross entropy for example).
# [Reference : Sergios Karagiannakos]

# %% [markdown]
# ### Load the packages

# %%
# ============== Packages ===================
# %%capture
# %pip install bff
# %pip install --upgrade tensorflow
import re
import bff
import math
import pickle
import pprint
import statistics
import numpy as np
import collections
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import bff.plot as bplt
from pathlib import Path
import matplotlib as mpl
from itertools import cycle
from datetime import datetime
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from sklearn import preprocessing
import matplotlib.patches as mpatches
from typing import Callable, Dict, List, Sequence, Tuple, Union
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Imports for model
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import mse, binary_crossentropy, MeanSquaredError
from tensorflow.keras.layers import Layer, Dense, Reshape, Conv2D, Conv2DTranspose, Flatten, MaxPooling2D, UpSampling2D

# %% [markdown]
# ### Loading MNIST dataset for digit "***2***"
#
# The MNIST is database of handwritten digits. The digits have been size-normalized and centered in a fixed-size image.
#
# In this section we also split our data into training and testing datasets.
#
# You are able to observe different digits.

# %%
# Loading MNIST dataset for especific number, you can change digit in num variable
num = 2

# MNIST dataset.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Select only number that choose in num.
train_filter = np.where((y_train == num))
test_filter = np.where((y_test == num))
x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

print(f'Size of train: {y_train.shape}')
print(f'Size of test: {y_test.shape}')

# Resize the images and normalize between [0, 1].
image_size = x_train.shape[1]
x_train = x_train.reshape(x_train.shape[0], image_size, image_size, 1).astype('float32') / 255
x_test = x_test.reshape(x_test.shape[0], image_size, image_size, 1).astype('float32') / 255
print(f'Shape of training: {x_train.shape}')
print(f'Shape of testing: {x_test.shape}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Size of train: (5958,)
# Size of test: (1032,)
# Shape of training: (5958, 28, 28, 1)
# Shape of testing: (1032, 28, 28, 1)

# %% [markdown]
# ### Examples of digit ***"2"*** from dataset

# %%
# Examples of 2
_, axes = plt.subplots(10, 10, figsize=(10, 10))

for i, ax in enumerate(tqdm(axes.flatten())):
  ax.xaxis.set_major_locator(plt.NullLocator())
  ax.yaxis.set_major_locator(plt.NullLocator())
  if len(x_train.shape) < 3:
      size = int(np.sqrt(x_train[i].shape[0]))
  else:
      size = x_train.shape[1]
  ax.imshow(x_train[i].reshape(size, size), cmap='gray_r')
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1528.11it/s]

# %% [markdown]
# ### Reconstructing Variational Autoencoder

# %%
class Sampling(Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a serie."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        # By default, random_normal has mean=0 and std=1.0.
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class Encoder(Layer):
    """Maps series to a triplet (z_mean, z_log_var, z)."""

    def __init__(self,
                 latent_dim=2,
                 name='encoder',
                 **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)
        self.conv_1 = Conv2D(filters=32, kernel_size=3, activation='relu', strides=2, padding='same')
        self.conv_2 = Conv2D(filters=64, kernel_size=3, activation='relu', strides=2, padding='same')
        self.flatten = Flatten()
        self.dense_before_latent = Dense(16, activation='relu')
        self.dense_mean = Dense(latent_dim, name='z_mean')
        self.dense_log_var = Dense(latent_dim, name='z_log_var')
        self.sampling = Sampling()
  
    def call(self, inputs):
        x = self.conv_1(inputs)
        x = self.conv_2(x)
        shape = K.int_shape(x)
        #print(K.int_shape(x))
        # Generate latent vector.
        x = self.flatten(x)
        x = self.dense_before_latent(x)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z


class Decoder(Layer):
    """Converts z, the encoded vector, back into a readable series."""
  
    def __init__(self,
                 original_dim,
                 name='decoder',
                 **kwargs):
        super(Decoder, self).__init__(name=name, **kwargs)
        self.dense_proj = Dense(7*7*64, activation='relu')
        self.reshape = Reshape(target_shape=(7, 7, 64))
        self.conv_1 = Conv2DTranspose(filters=64, kernel_size=3, activation='relu', strides=2, padding='same')
        self.conv_2 = Conv2DTranspose(filters=32, kernel_size=3, activation='relu', strides=2, padding='same')
        self.conv_output = Conv2DTranspose(filters=1, kernel_size=3, activation='sigmoid', padding='same')
  
    def call(self, inputs):
        x = self.dense_proj(inputs)
        x = self.reshape(x)
        x = self.conv_1(x)
        x = self.conv_2(x)
        return self.conv_output(x)


class VariationalAutoEncoder(Model):
    """Combines the encoder and decoder into an end-to-end model for training."""
  
    def __init__(self,
                 original_dim,
                 latent_dim=32,
                 name='autoencoder',
                 **kwargs):
        super(VariationalAutoEncoder, self).__init__(name=name, **kwargs)
        self.original_dim = original_dim
        self.encoder = Encoder(latent_dim=latent_dim)
        self.decoder = Decoder(original_dim)
  
    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstructed = self.decoder(z)
        
        # Add KL divergence regularization loss.
        reconstruction_loss = binary_crossentropy(K.flatten(inputs), K.flatten(reconstructed))
        reconstruction_loss *= self.original_dim
        kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
        kl_loss = K.sum(kl_loss, axis=-1)
        kl_loss *= -0.5
        vae_loss = K.mean(reconstruction_loss + kl_loss)
        self.add_loss(vae_loss)
        
        return reconstructed

# %% [markdown]
# ### Different sizes of dataset for fitting the variational autoencoder
#
# In this step, you fit variational autoencoder model to different sizes of train dataset:
#
# 1.   *whole dataset*
# 2.   *1000 samples of dataset*
# 3.   *100 samples of dataset*
# 4.   *10 samples of dataset*
#
#
# Observe different sizes of samples and their model losses.

# %%
models = {}

training_sizes = [x_train.shape[0], 1000, 100, 10] # different sizes of train dataset

for size_training in training_sizes:
    #size_training = x_train.shape[0]
    x_train_filter = x_train[:size_training]

    print(f'Training using {size_training} examples.')
    print(f'Shape of training: {x_train_filter.shape}')

    # Size of layers
    original_dim = x_train_filter.shape[1] # Should be 784.
    latent_dim = 2

    # Parameters for training.
    batch_size = 16 if size_training > 100 else 1
    epochs = 50

    vae = VariationalAutoEncoder(original_dim, 
                                 latent_dim=latent_dim)

    optimizer = Adam(learning_rate=1e-3)

    # Define the Keras TensorBoard callback.
    #logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
    #tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

    # Losses are MSE with KL divergence.
    vae.compile(optimizer)
    history = vae.fit(x_train_filter,
                      epochs=epochs, 
                      batch_size=batch_size, 
                      validation_split=0.2, 
                      verbose=1)
                      #callbacks=[tensorboard_callback])
    #plot_model(vae, to_file='vae-cnn.png')
    vae.summary()
    
    models[size_training] = (history, vae)


#plot_model(vae, to_file='11-VAE_MLP_-OBJ.png', show_shapes=True, expand_nested=True)
# Out:
# Training using 5958 examples.
# Shape of training: (5958, 28, 28, 1)
# Train on 4766 samples, validate on 1192 samples
# Epoch 1/50
# 4766/4766 [==============================] - 12s 3ms/sample - loss: 8.7731 - val_loss: 7.3572
# Epoch 2/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.3418 - val_loss: 7.2838
# Epoch 3/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.3036 - val_loss: 7.2519
# Epoch 4/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2916 - val_loss: 7.2659
# Epoch 5/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2896 - val_loss: 7.2509
# Epoch 6/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2882 - val_loss: 7.2503
# Epoch 7/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2856 - val_loss: 7.2528
# Epoch 8/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2830 - val_loss: 7.2493
# Epoch 9/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2824 - val_loss: 7.2443
# Epoch 10/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2816 - val_loss: 7.2497
# Epoch 11/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2816 - val_loss: 7.2413
# Epoch 12/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2842 - val_loss: 7.2604
# Epoch 13/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2744 - val_loss: 7.2531
# Epoch 14/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2768 - val_loss: 7.2368
# Epoch 15/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2775 - val_loss: 7.2377
# Epoch 16/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2730 - val_loss: 7.2176
# Epoch 17/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2800 - val_loss: 7.2467
# Epoch 18/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2737 - val_loss: 7.2412
# Epoch 19/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2703 - val_loss: 7.2534
# Epoch 20/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2732 - val_loss: 7.2613
# Epoch 21/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2725 - val_loss: 7.2417
# Epoch 22/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2663 - val_loss: 7.2452
# Epoch 23/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2708 - val_loss: 7.2364
# Epoch 24/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2816 - val_loss: 7.2232
# Epoch 25/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2748 - val_loss: 7.2333
# Epoch 26/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2709 - val_loss: 7.2285
# Epoch 27/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2621 - val_loss: 7.2547
# Epoch 28/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2668 - val_loss: 7.2331
# Epoch 29/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2706 - val_loss: 7.2400
# Epoch 30/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2654 - val_loss: 7.2429
# Epoch 31/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2642 - val_loss: 7.2417
# Epoch 32/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2728 - val_loss: 7.2396
# Epoch 33/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2713 - val_loss: 7.2247
# Epoch 34/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2686 - val_loss: 7.2276
# Epoch 35/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2570 - val_loss: 7.2299
# Epoch 36/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2626 - val_loss: 7.2340
# Epoch 37/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2696 - val_loss: 7.2005
# Epoch 38/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2614 - val_loss: 7.2382
# Epoch 39/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2711 - val_loss: 7.2216
# Epoch 40/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2602 - val_loss: 7.2396
# Epoch 41/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2583 - val_loss: 7.2195
# Epoch 42/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2516 - val_loss: 7.2314
# Epoch 43/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2757 - val_loss: 7.2447
# Epoch 44/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2566 - val_loss: 7.2212
# Epoch 45/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2604 - val_loss: 7.2441
# Epoch 46/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2509 - val_loss: 7.2300
# Epoch 47/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2718 - val_loss: 7.2370
# Epoch 48/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2807 - val_loss: 7.2389
# Epoch 49/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2595 - val_loss: 7.2024
# Epoch 50/50
# 4766/4766 [==============================] - 11s 2ms/sample - loss: 7.2678 - val_loss: 7.2145
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Encoder)            multiple                  69076
# _________________________________________________________________
# decoder (Decoder)            multiple                  65089
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________
# Training using 1000 examples.
# Shape of training: (1000, 28, 28, 1)
# Train on 800 samples, validate on 200 samples
# Epoch 1/50
# 800/800 [==============================] - 3s 4ms/sample - loss: 12.7922 - val_loss: 8.6565
# Epoch 2/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.9108 - val_loss: 7.6696
# Epoch 3/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.5035 - val_loss: 7.4300
# Epoch 4/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.4032 - val_loss: 7.3591
# Epoch 5/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.3642 - val_loss: 7.2978
# Epoch 6/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.3414 - val_loss: 7.3151
# Epoch 7/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.3330 - val_loss: 7.3258
# Epoch 8/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.3227 - val_loss: 7.3214
# Epoch 9/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.3077 - val_loss: 7.3004
# Epoch 10/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.3085 - val_loss: 7.3175
# Epoch 11/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.3155 - val_loss: 7.2737
# Epoch 12/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2978 - val_loss: 7.2954
# Epoch 13/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2878 - val_loss: 7.2732
# Epoch 14/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2904 - val_loss: 7.2979
# Epoch 15/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2901 - val_loss: 7.2890
# Epoch 16/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2770 - val_loss: 7.2710
# Epoch 17/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2731 - val_loss: 7.2464
# Epoch 18/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2684 - val_loss: 7.2687
# Epoch 19/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2670 - val_loss: 7.2516
# Epoch 20/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2572 - val_loss: 7.2483
# Epoch 21/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2715 - val_loss: 7.2647
# Epoch 22/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2630 - val_loss: 7.2643
# Epoch 23/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2600 - val_loss: 7.2581
# Epoch 24/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2844 - val_loss: 7.2409
# Epoch 25/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2663 - val_loss: 7.2402
# Epoch 26/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2603 - val_loss: 7.2459
# Epoch 27/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2506 - val_loss: 7.2364
# Epoch 28/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2558 - val_loss: 7.2387
# Epoch 29/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2583 - val_loss: 7.2347
# Epoch 30/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2439 - val_loss: 7.2274
# Epoch 31/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2387 - val_loss: 7.2492
# Epoch 32/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2474 - val_loss: 7.2364
# Epoch 33/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2455 - val_loss: 7.2396
# Epoch 34/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2397 - val_loss: 7.2195
# Epoch 35/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2449 - val_loss: 7.2386
# Epoch 36/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2394 - val_loss: 7.2352
# Epoch 37/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2414 - val_loss: 7.2336
# Epoch 38/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2389 - val_loss: 7.2272
# Epoch 39/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2348 - val_loss: 7.2324
# Epoch 40/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2315 - val_loss: 7.2243
# Epoch 41/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2400 - val_loss: 7.2215
# Epoch 42/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2340 - val_loss: 7.2634
# Epoch 43/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2404 - val_loss: 7.2223
# Epoch 44/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2341 - val_loss: 7.2284
# Epoch 45/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2337 - val_loss: 7.2566
# Epoch 46/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2402 - val_loss: 7.2177
# Epoch 47/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2301 - val_loss: 7.2204
# Epoch 48/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2247 - val_loss: 7.2207
# Epoch 49/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2277 - val_loss: 7.2112
# Epoch 50/50
# 800/800 [==============================] - 2s 2ms/sample - loss: 7.2301 - val_loss: 7.2206
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Encoder)            multiple                  69076
# _________________________________________________________________
# decoder (Decoder)            multiple                  65089
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________
# Training using 100 examples.
# Shape of training: (100, 28, 28, 1)
# Train on 80 samples, validate on 20 samples
# Epoch 1/50
# 80/80 [==============================] - 2s 20ms/sample - loss: 12.1511 - val_loss: 9.0442
# Epoch 2/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 8.1977 - val_loss: 8.1038
# Epoch 3/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 7.7274 - val_loss: 8.0340
# Epoch 4/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 7.6435 - val_loss: 7.8513
# Epoch 5/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 7.5253 - val_loss: 7.8269
# Epoch 6/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 7.5133 - val_loss: 7.8598
# Epoch 7/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.4784 - val_loss: 7.8350
# Epoch 8/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.4615 - val_loss: 7.7764
# Epoch 9/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.4569 - val_loss: 7.7935
# Epoch 10/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 7.3802 - val_loss: 7.7007
# Epoch 11/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 7.4017 - val_loss: 7.8381
# Epoch 12/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 7.3926 - val_loss: 7.6489
# Epoch 13/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 7.4049 - val_loss: 7.7993
# Epoch 14/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.4186 - val_loss: 7.7303
# Epoch 15/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3652 - val_loss: 7.8103
# Epoch 16/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3827 - val_loss: 7.7718
# Epoch 17/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3124 - val_loss: 7.7525
# Epoch 18/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3937 - val_loss: 7.7028
# Epoch 19/50
# 80/80 [==============================] - 1s 7ms/sample - loss: 7.4572 - val_loss: 7.8685
# Epoch 20/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3277 - val_loss: 7.6905
# Epoch 21/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3442 - val_loss: 7.7470
# Epoch 22/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3510 - val_loss: 7.7277
# Epoch 23/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3842 - val_loss: 7.8471
# Epoch 24/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2365 - val_loss: 7.6419
# Epoch 25/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3319 - val_loss: 7.8121
# Epoch 26/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2905 - val_loss: 7.6027
# Epoch 27/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3310 - val_loss: 8.0703
# Epoch 28/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3044 - val_loss: 7.6979
# Epoch 29/50
# 80/80 [==============================] - 1s 7ms/sample - loss: 7.3310 - val_loss: 7.7980
# Epoch 30/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3032 - val_loss: 7.6640
# Epoch 31/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2858 - val_loss: 7.6458
# Epoch 32/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2543 - val_loss: 8.1390
# Epoch 33/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3251 - val_loss: 7.6286
# Epoch 34/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2144 - val_loss: 7.8085
# Epoch 35/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.1656 - val_loss: 7.8089
# Epoch 36/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2426 - val_loss: 7.8590
# Epoch 37/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2441 - val_loss: 7.8153
# Epoch 38/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2625 - val_loss: 7.5201
# Epoch 39/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3515 - val_loss: 7.5519
# Epoch 40/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2890 - val_loss: 7.8169
# Epoch 41/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3185 - val_loss: 7.7084
# Epoch 42/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3336 - val_loss: 7.7741
# Epoch 43/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3498 - val_loss: 7.8463
# Epoch 44/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 7.2896 - val_loss: 7.4437
# Epoch 45/50
# 80/80 [==============================] - 1s 9ms/sample - loss: 7.2674 - val_loss: 8.1433
# Epoch 46/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.0891 - val_loss: 8.0711
# Epoch 47/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.1748 - val_loss: 7.8447
# Epoch 48/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2145 - val_loss: 7.8404
# Epoch 49/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.2300 - val_loss: 7.6928
# Epoch 50/50
# 80/80 [==============================] - 1s 8ms/sample - loss: 7.3161 - val_loss: 7.6282
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Encoder)            multiple                  69076
# _________________________________________________________________
# decoder (Decoder)            multiple                  65089
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________
# Training using 10 examples.
# Shape of training: (10, 28, 28, 1)
# Train on 8 samples, validate on 2 samples
# Epoch 1/50
# 8/8 [==============================] - 1s 145ms/sample - loss: 19.0123 - val_loss: 18.4116
# Epoch 2/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 17.2364 - val_loss: 15.2253
# Epoch 3/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 14.2670 - val_loss: 13.8751
# Epoch 4/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 13.0657 - val_loss: 11.4578
# Epoch 5/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 11.5182 - val_loss: 10.8981
# Epoch 6/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 11.1826 - val_loss: 10.0850
# Epoch 7/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 10.4209 - val_loss: 10.1680
# Epoch 8/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 9.6856 - val_loss: 9.0933
# Epoch 9/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 9.3226 - val_loss: 10.9442
# Epoch 10/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 8.9370 - val_loss: 8.6493
# Epoch 11/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 8.4798 - val_loss: 8.5056
# Epoch 12/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 8.5644 - val_loss: 8.4784
# Epoch 13/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 8.2547 - val_loss: 8.5391
# Epoch 14/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.9519 - val_loss: 8.2448
# Epoch 15/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.8336 - val_loss: 8.1751
# Epoch 16/50
# 8/8 [==============================] - 0s 11ms/sample - loss: 8.1947 - val_loss: 8.4391
# Epoch 17/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.9099 - val_loss: 8.3917
# Epoch 18/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 8.4544 - val_loss: 8.4108
# Epoch 19/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.7123 - val_loss: 8.1426
# Epoch 20/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 8.0248 - val_loss: 7.8798
# Epoch 21/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.7081 - val_loss: 8.2513
# Epoch 22/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.6244 - val_loss: 7.9360
# Epoch 23/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 8.0641 - val_loss: 8.1636
# Epoch 24/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.5909 - val_loss: 8.1858
# Epoch 25/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.7059 - val_loss: 8.2458
# Epoch 26/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.7195 - val_loss: 8.0996
# Epoch 27/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.8272 - val_loss: 8.2094
# Epoch 28/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.5736 - val_loss: 7.9032
# Epoch 29/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.6157 - val_loss: 7.8709
# Epoch 30/50
# 8/8 [==============================] - 0s 10ms/sample - loss: 7.5549 - val_loss: 8.3441
# Epoch 31/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.4800 - val_loss: 8.3610
# Epoch 32/50
# 8/8 [==============================] - 0s 10ms/sample - loss: 7.6306 - val_loss: 8.1983
# Epoch 33/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.4678 - val_loss: 7.9772
# Epoch 34/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.5089 - val_loss: 7.7759
# Epoch 35/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.4126 - val_loss: 7.9570
# Epoch 36/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.6134 - val_loss: 8.0789
# Epoch 37/50
# 8/8 [==============================] - 0s 10ms/sample - loss: 7.5244 - val_loss: 8.0995
# Epoch 38/50
# 8/8 [==============================] - 0s 10ms/sample - loss: 7.5016 - val_loss: 7.9249
# Epoch 39/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.5876 - val_loss: 7.9505
# Epoch 40/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.5168 - val_loss: 8.0731
# Epoch 41/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.8915 - val_loss: 7.9222
# Epoch 42/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.5750 - val_loss: 7.8848
# Epoch 43/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.4597 - val_loss: 7.9421
# Epoch 44/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.4162 - val_loss: 8.0621
# Epoch 45/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.3923 - val_loss: 7.9909
# Epoch 46/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.3677 - val_loss: 8.0330
# Epoch 47/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.3882 - val_loss: 8.0324
# Epoch 48/50
# 8/8 [==============================] - 0s 9ms/sample - loss: 7.3625 - val_loss: 8.1229
# Epoch 49/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.5909 - val_loss: 8.2514
# Epoch 50/50
# 8/8 [==============================] - 0s 8ms/sample - loss: 7.4268 - val_loss: 8.0411
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Encoder)            multiple                  69076
# _________________________________________________________________
# decoder (Decoder)            multiple                  65089
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Loss
# Model losses for 4 different dataset.

# %%
_, axes = plt.subplots(nrows=len(training_sizes), ncols=1, figsize=(10, 10), constrained_layout=True)
axes = axes.flatten()

for i, size in enumerate(training_sizes):
    history = models[size][0]
    history.history['val_loss'] = history.history.get('val_loss', [0])
    bplt.plot_history(history.history, axes=axes[i])

# %% [markdown]
# ### Uploading pretrained model that can predict digits.
# Uploading pretrained model in order to see how much the variational autoencoder were successful in reconstructing digits that can be recognize by MNIST model.
#
# You need to upload **cnn.h5** file inside **Models** folder from provided folder.

# %%
# Loading a pretrained model
model_mnist = load_model('cnn.h5')
model_mnist.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               1179776
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Predictions based on different sizes of dataset**

# %%
def predict_digit(model_mnist, img):
    digits = np.squeeze(model_mnist.predict(img))
    digit = np.where(digits == np.amax(digits))[0][0]
    return digit

# %%
COLORS = ['spring', 'Wistia', 'gray', 'summer', 'hot',
          'winter', 'afmhot', 'autumn', 'gist_heat', 'copper'] # colormap for digits from 0 to 9

for size_train, (_, vae) in models.items():
    # Example of digits from dataset.
    fig, axes = plt.subplots(10, 10, figsize=(10, 10))

    # Create random numbers for the decoder.
    randoms = np.array([np.random.uniform(-2, 2, latent_dim) for _ in range(10 * 10)]).astype('float32')
    predictions = vae.decoder(randoms).numpy()

    for i, ax in enumerate(tqdm(axes.flatten())):
        ax.xaxis.set_major_locator(plt.NullLocator())
        ax.yaxis.set_major_locator(plt.NullLocator())
        if len(x_test.shape) < 3:
            size = int(np.sqrt(x_test[i].shape[0]))
        else:
            size = x_test.shape[1]
        ax.imshow(predictions[i].reshape(size, size), cmap=COLORS[predict_digit(model_mnist, np.expand_dims(predictions[i], axis=0))])
    fig.suptitle(f'Predictions with size {size_train}')
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 25.61it/s]
# 100%|██████████| 100/100 [00:03<00:00, 29.37it/s]
# 100%|██████████| 100/100 [00:03<00:00, 29.14it/s]
# 100%|██████████| 100/100 [00:04<00:00, 23.91it/s]

# %% [markdown]
# #### Try to change the latent layer to observe how classifying digits with MNIST model is gonna change.

# %%
for size_train, (_, vae) in models.items():
    _, axes = plt.subplots(14, 14, figsize=(10, 10))

    # Create random numbers for the decoder.
    values = np.arange(-3, 4, .5)
    xx, yy = np.meshgrid(values, values)
    input_holder = np.zeros((1, latent_dim))

    for row in range(xx.shape[0]):
        for col in range(xx.shape[1]):
            input_holder[0, :] = [xx[row, col], yy[row, col]]
            axes[row][col].xaxis.set_major_locator(plt.NullLocator())
            axes[row][col].yaxis.set_major_locator(plt.NullLocator())
            img = vae.decoder(input_holder).numpy()

            digit = predict_digit(model_mnist, img)

            axes[row][col].imshow(img.reshape(size, size), cmap=COLORS[digit])

# %%
for size_train, (_, vae) in models.items():
    _, axes = plt.subplots(14, 14, figsize=(10, 10))

    # Create random numbers for the decoder.
    values = np.arange(-7, 7, 1)
    xx, yy = np.meshgrid(values, values)
    input_holder = np.zeros((1, latent_dim))

    for row in range(xx.shape[0]):
        for col in range(xx.shape[1]):
            input_holder[0, :] = [xx[row, col], yy[row, col]]
            axes[row][col].xaxis.set_major_locator(plt.NullLocator())
            axes[row][col].yaxis.set_major_locator(plt.NullLocator())
            img = vae.decoder(input_holder).numpy()

            digit = predict_digit(model_mnist, img)

            axes[row][col].imshow(img.reshape(size, size), cmap=COLORS[digit])
